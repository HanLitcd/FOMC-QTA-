# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def fetch_page_content(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        return None
def find_speech_links(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    # Assuming each link is in an <a> tag within a list or table of speeches
    # You'll need to adjust the selector based on the actual HTML structure
    links = soup.find_all('a', href=True)
    speech_links = []
    for link in links:
        # Filter out the links that don't lead to speeches or adjust the condition based on the URL pattern
        if 'newsevents/speech' in link['href']:
            full_url = f"https://www.federalreserve.gov{link['href']}"
            speech_links.append(full_url)
    return speech_links
def fetch_yearly_speech_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    speech_links = []
    
    # Assuming each link to a speech is within an <a> tag directly under the specified container
    # You might need to adjust the selector based on the actual page structure
    for a in soup.find_all('a', href=True):
        if '/newsevents/speech/' in a['href']:
            full_url = f"https://www.federalreserve.gov{a['href']}"
            speech_links.append(full_url)
    
    return speech_links
def fetch_speech_links(url):
    main_page_content = fetch_page_content(url)
    if main_page_content:
        return find_speech_links(main_page_content)
    else:
        return []

def parse_speech_data(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Adjusting the selectors based on the provided HTML structure
    date = soup.find('p', class_='article__time').get_text(strip=True)
    speaker = soup.find('p', class_='speaker').get_text(strip=True)
    location = soup.find('p', class_='location').get_text(strip=True)
    
    # Finding the main article content
    speech_text = ''
    article = soup.find(id='article')
    if article:
        # Extract all <p> elements and join their texts
        paragraphs = article.find_all('p')
        speech_text = '\n\n'.join(paragraph.get_text(strip=True) for paragraph in paragraphs)
    
    return {
        'Date': date,
        'Speaker': speaker,
        'Location': location,
        'Text': speech_text
    }
def scrape_speech_data(speech_url):
    # Fetch an individual speech page and extract the text and metadata
    html_content = fetch_page_content(speech_url)
    if html_content:
        return parse_speech_data(html_content)
    else:
        return None

# %%
years = ['2024','2023', '2022', '2021','2020']
base_url = 'https://www.federalreserve.gov/newsevents/speech/{}-speeches.htm'
all_speeches = []

for year in years:
    yearly_url = base_url.format(year)
    speech_links = fetch_yearly_speech_links(yearly_url)
        
    for link in speech_links:
        speech_data = scrape_speech_data(link)
        all_speeches.append(speech_data)
            # Here, you might want to pause or print progress
            
    # Now all_speeches contains speech data for the last 3 years
    # You can convert this to a DataFrame or process as needed
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-132-eabcd8a48ea6> in <module>
#       8
#       9     for link in speech_links:
# ---> 10         speech_data = scrape_speech_data(link)
#      11         all_speeches.append(speech_data)
#      12             # Here, you might want to pause or print progress
#
# <ipython-input-131-bf97d1ca39dc> in scrape_speech_data(speech_url)
#      63     html_content = fetch_page_content(speech_url)
#      64     if html_content:
# ---> 65         return parse_speech_data(html_content)
#      66     else:
#      67         return None
#
# <ipython-input-131-bf97d1ca39dc> in parse_speech_data(html_content)
#      38
#      39 def parse_speech_data(html_content):
# ---> 40     soup = BeautifulSoup(html_content, 'html.parser')
#      41
#      42     # Adjusting the selectors based on the provided HTML structure
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333             self.builder.initialize_soup(self)
#     334             try:
# --> 335                 self._feed()
#     336                 success = True
#     337                 break
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in _feed(self)
#     476         self.builder.reset()
#     477
# --> 478         self.builder.feed(self.markup)
#     479         # Close out any unfinished strings and close all the open tags.
#     480         self.endData()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     378         parser.soup = self.soup
#     379         try:
# --> 380             parser.feed(markup)
#     381         except AssertionError as e:
#     382             # html.parser raises AssertionError in rare cases to
#
# ~/opt/anaconda3/lib/python3.8/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/html/parser.py in goahead(self, end)
#     236                     # not the end of the buffer, and can't be confused
#     237                     # with some other construct
# --> 238                     self.handle_data("&")
#     239                     i = self.updatepos(i, i + 1)
#     240                 else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/builder/_htmlparser.py in handle_data(self, data)
#     176             self.soup.handle_endtag(name)
#     177
# --> 178     def handle_data(self, data):
#     179         """Handle some textual data that shows up between tags."""
#     180         self.soup.handle_data(data)
#
# KeyboardInterrupt:

# %%
speech_df =pd.DataFrame(all_speeches)
speech_df=speech_df.drop_duplicates(subset='Text')
speech_df.Location.value_counts().index

# %%
#speech_df.to_csv('speeches.csv')
speech_df
# Out:
#                   Date                                       Speaker  \
# 0    February 16, 2024    Vice Chair for Supervision Michael S. Barr
# 1    February 15, 2024                Governor Christopher J. Waller
# 2    February 15, 2024                   Governor Michelle W. Bowman
# 3    February 14, 2024    Vice Chair for Supervision Michael S. Barr
# 4    February 12, 2024                   Governor Michelle W. Bowman
# ..                 ...                                           ...
# 275  February 05, 2020                        Governor Lael Brainard
# 276   January 17, 2020  Vice Chair for Supervision Randal K. Quarles
# 277   January 16, 2020                   Governor Michelle W. Bowman
# 278   January 09, 2020                 Vice Chair Richard H. Clarida
# 279   January 08, 2020                        Governor Lael Brainard
#
#                                               Location  \
# 0    At the Annual Columbia Law School Banking Conf...
# 1    At "Climate, Currency, and Central Banking," a...
# 2    At the 19th BCBS-FSI High-Level Meeting for Af...
# 3    At the 40th Annual National Association for Bu...
# 4    At the American Bankers Association 2024 Confe...
# ..                                                 ...
# 275  At the Symposium on the Future of Payments, St...
# 276  At the American Bar Association Banking Law Co...
# 277  At the 2020 Economic Forecast Breakfast, Home ...
# 278  At the C. Peter McColough Series on Internatio...
# 279           At the Urban Institute, Washington, D.C.
#
#                                                   Text
# 0    February 16, 2024\n\nVice Chair for Supervisio...
# 1    February 15, 2024\n\nGovernor Christopher J. W...
# 2    February 15, 2024\n\nGovernor Michelle W. Bowm...
# 3    February 14, 2024\n\nVice Chair for Supervisio...
# 4    February 12, 2024\n\nGovernor Michelle W. Bowm...
# ..                                                 ...
# 275  February 05, 2020\n\nGovernor Lael Brainard\n\...
# 276  January 17, 2020\n\nVice Chair for Supervision...
# 277  January 16, 2020\n\nGovernor Michelle W. Bowma...
# 278  January 09, 2020\n\nVice Chair Richard H. Clar...
# 279  January 08, 2020\n\nGovernor Lael Brainard\n\n...
#
# [274 rows x 4 columns]

# %%
pattern = r'\s*(via\s+.*|virtual|and by webcast)'
speech_df['Location']=speech_df.Location.str.replace('At the','').replace('via webcast','')
speech_df['Location']=speech_df.Location.str.replace('via webcast','')
speech_df['Location']=speech_df['Location'].str.replace(pattern, '', regex=True)
speech_df['Location']=speech_df.Location.str.replace('(','')
speech_df['Location']=speech_df.Location.str.replace(')','')
#speech_df['Location']=speech_df.Location.str.replace('and','')

speech_df['Location']=speech_df.Location.str.split(',').str[-1].str.strip()
speech_df.Location.value_counts()
# Out:
# <ipython-input-110-f6262162f632>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   speech_df['Location']=speech_df.Location.str.replace('(','')
# <ipython-input-110-f6262162f632>:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   speech_df['Location']=speech_df.Location.str.replace(')','')
# D.C.                                                                                                           78
# New York                                                                                                       25
# California                                                                                                     16
# Massachusetts                                                                                                   9
# Ohio                                                                                                            9
#                                                                                                                ..
# At National Native Coalition Virtual Series on the Community Reinvestment Act Notice of Proposed Rulemaking     1
# "Recent Fiscal and Monetary Policy: Implications for U.S. and Israeli Real Estate Markets" conference           1
# the Reserve Bank of New Zealand                                                                                 1
# and the European Central Bank                                                                                   1
# Connecticut                                                                                                     1
# Name: Location, Length: 80, dtype: int64

# %%
developed_countries = {"Austria", "Canada", "Germany", "Ireland", "Italy", "New Zealand", "Norway", "Spain", "Sweden", "Switzerland", "United Kingdom"}
emerging_markets = {"Morocco", "South Africa",'Bahamas'}
us_states = {"Alabama", "Arizona", "Arkansas", "California", "Colorado", "D.C.", "DC", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Kentucky", "Louisiana", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Nevada", "New York", "North Carolina", "Ohio", "Oklahoma", "Pennsylvania", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Washington D.C.", "West Virginia", "Wyoming", "and Richmond", "and St. Louis",'Connecticut','FL','Montana','Kansas'}

# %%
def map_location_group(location):
    # Remove any additional information in parentheses for accurate matching
    clean_location = location.split(" (")[0].split('"')[0].strip()
    if clean_location in us_states:
        return 'US'
    elif clean_location in developed_countries:
        return 'Developed Countries'
    elif clean_location in emerging_markets:
        return 'Emerging Markets'
    else:
        return 'international_conferences'

speech_df['occasion']=speech_df.Location.map(map_location_group)
speech_df[speech_df.occasion=='international_conferences']['Location']
# Out:
# 138    At National Native Coalition Virtual Series on...
# 151    "Recent Fiscal and Monetary Policy: Implicatio...
# 161                      the Reserve Bank of New Zealand
# 166                        and the European Central Bank
# 180                                 Missouri  conference
# 183                                     D.C.  conference
# 193              At The Prudential Regulation Conference
# 196    National Association of Insurance Commissioner...
# 202    " a conference sponsored by the Society for Ad...
# 215                   Institute of International Bankers
# 219    "Advance Together" Celebration sponsored by th...
# 221    Conference for Community Bankers sponsored by ...
# 222                            Economic Club of New York
# 224    Inaugural Mike McCracken Lecture on Full Emplo...
# 225                                   D.C. Virtual Event
# 228    Consumer Bankers Association Community Reinves...
# 229                                           and Future
# 230    At Independent Community Bankers of America Th...
# 235    National Congress of American Indians 77th Ann...
# 236    "Post-COVIDâPolicy Challenges for the Global...
# 237    National Housing Conference National Advisory ...
# 238    Securities Industry and Financial Markets Asso...
# 240                  To the National Bankers Association
# 242
# 244    National Association for Business Economics Vi...
# 246    To the Independent Community Bankers of Americ...
# 262
# Name: Location, dtype: object

# %%
speech_df=pd.read_csv('5yearspeeches.csv')
#speech_df.loc[speech_df.Speaker=='Chair Pro Tempore Jerome H. Powell','Speaker']='Chair Jerome H. Powell'
#speech_df.loc[speech_df.Speaker=='Vice Chair Philip N. Jefferson','Speaker']='Governor Philip N. Jefferson'
#speech_df.loc[speech_df.Speaker=='Vice Chair for Supervision and Chair of the Financial Stability Board Randal K. Quarles','Speaker']='Governor Randal K. Quarles'
#speech_df.loc[speech_df.Speaker=='Governor Randal K. Quarles','Speaker']='Vice Chair for Supervision Randal K. Quarles'
speech_df.loc[speech_df.Speaker=='Vice Chair Lael Brainard','Speaker']='Governor Lael Brainard'
speech_df.Speaker.value_counts()
speech_df.to_csv('5yearspeeches.csv')

# %%
radar_data= pd.read_csv('radar_data.csv')
radar_data
# Out:
#    Unnamed: 0                                       Speaker     Doves  \
# 0           1                        Chair Jerome H. Powell  0.433333
# 1           2                    Governor Adriana D. Kugler  0.000000
# 2           3                Governor Christopher J. Waller  0.026316
# 3           4                        Governor Lael Brainard  0.333333
# 4           5                         Governor Lisa D. Cook  0.666667
# 5           6                   Governor Michelle W. Bowman  0.205882
# 6           7                  Governor Philip N. Jefferson  0.250000
# 7           8                 Vice Chair Richard H. Clarida  0.047619
# 8           9    Vice Chair for Supervision Michael S. Barr  0.315789
# 9          10  Vice Chair for Supervision Randal K. Quarles  0.409091
#
#       Hawks  Stability
# 0  0.333333   0.233333
# 1  1.000000   0.000000
# 2  0.552632   0.421053
# 3  0.288889   0.377778
# 4  0.333333   0.000000
# 5  0.397059   0.397059
# 6  0.666667   0.083333
# 7  0.333333   0.619048
# 8  0.473684   0.210526
# 9  0.454545   0.136364

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from math import pi
import numpy as np

# %%
def plot_adjusted_radar_chart(df):
    # Define the number of variables and their angle on the chart
    labels=np.array(['Doves', 'Hawks', 'Stability'])
    num_vars = len(labels)
    
    # Compute angle each bar is centered on:
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
    
    # The radar chart is a circle, so we need to "complete the loop" and append the start value to the end.
    angles += angles[:1]
    
    # Plot setup
    fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
    plt.xticks(angles[:-1], labels)
    
    # Draw one dot per speaker and add lines to close the circle for each speaker
    for index, row in df.iterrows():
        values = row[['Doves', 'Hawks', 'Stability']].values.flatten().tolist()
        values += values[:1]
        ax.plot(angles, values, marker='o', label=row['Speaker'])
    
    # Add legend
    plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

# %%
plot_adjusted_radar_chart(radar_data)

# %%
import seaborn as sns
import pandas as pd
# %matplotlib qt
# Assuming 'df' is your DataFrame from earlier

# Convert the Speaker column into a categorical type if it's not already
radar_data['Speaker'] = pd.Categorical(radar_data['Speaker'])
palette = sns.color_palette("tab20", len(set(radar_data.Speaker)))
# Use seaborn's pairplot function to create the scatter plot matrix
g= sns.pairplot(radar_data, hue='Speaker', vars=['Doves', 'Hawks', 'Stability'], palette=palette, markers='o', 
                 height=5, aspect=1,plot_kws={'alpha':0.8, 's': 200})
# Map the plots to the grid

g = g.map_offdiag(plt.scatter, alpha=0.5, s=50)

# Set the axis limits
g.set(xlim=(0, 1.1), ylim=(0, 1.1))
# Add a legend with customized font sizes
#g.add_legend(title='Speaker', title_fontsize='13', fontsize='10')

# Adjust global font sizes for axes and ticks
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['legend.title_fontsize'] = 20
plt.rcParams['legend.fontsize'] = 20
# Show the plot
plt.show()
# Out:
# /Users/ves/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# /Users/ves/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ves/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ves/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ####

# %%
len(set(radar_data.Speaker))

# %%
radar_data
# Out:
#    Unnamed: 0                                       Speaker     Doves  \
# 0           1                        Chair Jerome H. Powell  0.433333
# 1           2                    Governor Adriana D. Kugler  0.000000
# 2           3                Governor Christopher J. Waller  0.026316
# 3           4                        Governor Lael Brainard  0.333333
# 4           5                         Governor Lisa D. Cook  0.666667
# 5           6                   Governor Michelle W. Bowman  0.205882
# 6           7                  Governor Philip N. Jefferson  0.250000
# 7           8                 Vice Chair Richard H. Clarida  0.047619
# 8           9    Vice Chair for Supervision Michael S. Barr  0.315789
# 9          10  Vice Chair for Supervision Randal K. Quarles  0.409091
#
#       Hawks  Stability  Hawk_Proportion  Rescaled_Hawkishness
# 0  0.333333   0.233333         0.434783             -0.262364
# 1  1.000000   0.000000         1.000000                   inf
# 2  0.552632   0.421053         0.954545              3.044522
# 3  0.288889   0.377778         0.464286             -0.143101
# 4  0.333333   0.000000         0.333333             -0.693147
# 5  0.397059   0.397059         0.658537              0.656780
# 6  0.666667   0.083333         0.727273              0.980829
# 7  0.333333   0.619048         0.875000              1.945910
# 8  0.473684   0.210526         0.600000              0.405465
# 9  0.454545   0.136364         0.526316              0.105361

# %%
radar_data['Hawk_Proportion'] = radar_data['Hawks'] / (radar_data['Hawks'] + radar_data['Doves'])
#radar_data['Rescaled_Hawkishness'] = np.log(radar_data['Hawks']/radar_data['Doves'])#2 * (radar_data['Hawk_Proportion'] - 0.5)

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(radar_data['Rescaled_Hawkishness'], radar_data['Stability'], s=100, c='blue', alpha=0.5)
plt.axvline(x=0, color='grey', linestyle='--')
plt.axhline(y=0.5, color='grey', linestyle='--')  # Optional: if you want to mark the neutral stability line
plt.xlabel('Hawkishness (Dovish < 0 < Hawkish)')
plt.ylabel('Stability')
plt.title('Speaker Policy Inclinations')

# Annotate each point with the speaker's name for clarity
for i, txt in enumerate(radar_data['Speaker']):
    plt.annotate(txt, (radar_data['Rescaled_Hawkishness'][i], radar_data['Stability'][i]),fontsize=7)
plt.xlim(-1.5, 1.5)
plt.ylim(0, 1)
plt.show()

# %%
import pandas as pd
speeches= pd.read_csv('speeches.csv')
speeches.head()
# Out:
#    Unnamed: 0               Date                                     Speaker  \
# 0           0  February 15, 2024                 Governor Michelle W. Bowman
# 1           1  February 14, 2024  Vice Chair for Supervision Michael S. Barr
# 2           2  February 12, 2024                 Governor Michelle W. Bowman
# 3           3  February 07, 2024                 Governor Michelle W. Bowman
# 4           4  February 07, 2024                  Governor Adriana D. Kugler
#
#                          Location  \
# 0                    South Africa
# 1                            D.C.
# 2                           Texas
# 3   D.C. (via pre-recorded video)
# 4                            D.C.
#
#                                                 Text          occasion
# 0  February 15, 2024\n\nGovernor Michelle W. Bowm...  Emerging Markets
# 1  February 14, 2024\n\nVice Chair for Supervisio...                US
# 2  February 12, 2024\n\nGovernor Michelle W. Bowm...                US
# 3  February 07, 2024\n\nGovernor Michelle W. Bowm...                US
# 4  February 07, 2024\n\nGovernor Adriana D. Kugle...                US

# %%
import yfinance as yf

# %%
start_date = "2020-01-01"
end_date = "2024-02-17"

# Download Bitcoin price data using Yahoo Finance (yfinance)
price = yf.download(["BTC-USD","DX-Y.NYB"], start=start_date, end=end_date)
close=price['Close'].reset_index().ffill()
daily_return=close[['BTC-USD','DX-Y.NYB']]/close.shift(1)-1
daily_return['Date']=close['Date']
daily_return
# Out:
# [*********************100%%**********************]  2 of 2 completed
#        BTC-USD  DX-Y.NYB       Date
# 0          NaN       NaN 2020-01-01
# 1    -0.029819       NaN 2020-01-02
# 2     0.051452 -0.000103 2020-01-03
# 3     0.008955  0.000000 2020-01-04
# 4     0.000089  0.000000 2020-01-05
# ...        ...       ...        ...
# 1503  0.034462  0.000865 2024-02-12
# 1504 -0.004319  0.007584 2024-02-13
# 1505  0.041901 -0.002287 2024-02-14
# 1506  0.002158 -0.004011 2024-02-15
# 1507  0.004268  0.000000 2024-02-16
#
# [1508 rows x 3 columns]

# %%
speech_df.Date=='Governor Randal K. Quarles','
# Out:
# {'April 04, 2023',
#  'April 05, 2022',
#  'April 09, 2020',
#  'April 14, 2021',
#  'April 14, 2023',
#  'April 18, 2023',
#  'April 20, 2023',
#  'April 21, 2023',
#  'August 03, 2021',
#  'August 04, 2021',
#  'August 05, 2021',
#  'August 05, 2023',
#  'August 06, 2020',
#  'August 06, 2022',
#  'August 07, 2023',
#  'August 13, 2020',
#  'August 17, 2021',
#  'August 17, 2022',
#  'August 19, 2020',
#  'August 22, 2023',
#  'August 25, 2023',
#  'August 26, 2020',
#  'August 26, 2022',
#  'August 27, 2020',
#  'August 27, 2021',
#  'August 29, 2022',
#  'August 31, 2020',
#  'December 01, 2020',
#  'December 01, 2022',
#  'December 01, 2023',
#  'December 02, 2021',
#  'December 04, 2020',
#  'December 05, 2023',
#  'December 11, 2020',
#  'December 17, 2020',
#  'December 17, 2021',
#  'December 18, 2020',
#  'February 02, 2024',
#  'February 05, 2020',
#  'February 06, 2020',
#  'February 07, 2023',
#  'February 07, 2024',
#  'February 08, 2023',
#  'February 10, 2020',
#  'February 10, 2021',
#  'February 10, 2023',
#  'February 11, 2020',
#  'February 12, 2024',
#  'February 13, 2023',
#  'February 14, 2024',
#  'February 15, 2023',
#  'February 15, 2024',
#  'February 16, 2021',
#  'February 16, 2023',
#  'February 16, 2024',
#  'February 18, 2021',
#  'February 18, 2022',
#  'February 21, 2020',
#  'February 21, 2022',
#  'February 22, 2021',
#  'February 24, 2021',
#  'February 24, 2022',
#  'February 24, 2023',
#  'February 25, 2020',
#  'February 25, 2021',
#  'February 27, 2020',
#  'February 27, 2023',
#  'Governor Randal K. Quarles',
#  'January 06, 2023',
#  'January 08, 2020',
#  'January 08, 2021',
#  'January 08, 2024',
#  'January 09, 2020',
#  'January 10, 2023',
#  'January 12, 2021',
#  'January 13, 2021',
#  'January 16, 2020',
#  'January 16, 2024',
#  'January 17, 2020',
#  'January 17, 2024',
#  'January 19, 2023',
#  'January 20, 2023',
#  'January 21, 2023',
#  'July 08, 2022',
#  'July 10, 2023',
#  'July 11, 2021',
#  'July 13, 2023',
#  'July 14, 2020',
#  'July 14, 2022',
#  'July 18, 2023',
#  'July 19, 2022',
#  'July 30, 2021',
#  'June 01, 2021',
#  'June 03, 2021',
#  'June 03, 2022',
#  'June 16, 2020',
#  'June 16, 2023',
#  'June 17, 2022',
#  'June 18, 2022',
#  'June 19, 2020',
#  'June 22, 2023',
#  'June 23, 2021',
#  'June 23, 2022',
#  'June 25, 2023',
#  'June 28, 2021',
#  'June 29, 2023',
#  'March 01, 2021',
#  'March 02, 2021',
#  'March 02, 2023',
#  'March 03, 2023',
#  'March 09, 2023',
#  'March 14, 2023',
#  'March 18, 2021',
#  'March 18, 2022',
#  'March 21, 2022',
#  'March 22, 2021',
#  'March 23, 2021',
#  'March 24, 2022',
#  'March 25, 2021',
#  'March 27, 2023',
#  'March 29, 2021',
#  'March 29, 2023',
#  'March 31, 2023',
#  'May 03, 2021',
#  'May 05, 2020',
#  'May 05, 2021',
#  'May 05, 2023',
#  'May 06, 2022',
#  'May 11, 2021',
#  'May 11, 2023',
#  'May 12, 2021',
#  'May 12, 2023',
#  'May 13, 2020',
#  'May 13, 2021',
#  'May 13, 2023',
#  'May 15, 2023',
#  'May 17, 2021',
#  'May 18, 2023',
#  'May 19, 2023',
#  'May 21, 2020',
#  'May 24, 2021',
#  'May 24, 2022',
#  'May 24, 2023',
#  'May 25, 2022',
#  'May 26, 2021',
#  'May 30, 2022',
#  'May 31, 2023',
#  'November 06, 2023',
#  'November 07, 2023',
#  'November 08, 2021',
#  'November 08, 2023',
#  'November 09, 2021',
#  'November 09, 2023',
#  'November 10, 2020',
#  'November 13, 2023',
#  'November 14, 2023',
#  'November 16, 2020',
#  'November 16, 2022',
#  'November 16, 2023',
#  'November 17, 2020',
#  'November 17, 2021',
#  'November 17, 2022',
#  'November 19, 2020',
#  'November 19, 2021',
#  'November 28, 2022',
#  'November 28, 2023',
#  'November 29, 2021',
#  'November 30, 2021',
#  'November 30, 2022',
#  'October 01, 2020',
#  'October 02, 2023',
#  'October 04, 2022',
#  'October 04, 2023',
#  'October 05, 2021',
#  'October 06, 2020',
#  'October 06, 2022',
#  'October 07, 2021',
#  'October 07, 2023',
#  'October 09, 2023',
#  'October 10, 2022',
#  'October 10, 2023',
#  'October 11, 2023',
#  'October 12, 2021',
#  'October 12, 2022',
#  'October 13, 2021',
#  'October 14, 2020',
#  'October 14, 2022',
#  'October 15, 2020',
#  'October 17, 2023',
#  'October 18, 2021',
#  'October 18, 2023',
#  'October 19, 2020',
#  'October 19, 2021',
#  'October 19, 2023',
#  'October 20, 2020',
#  'October 20, 2021',
#  'October 20, 2022',
#  'October 21, 2020',
#  'October 22, 2021',
#  'October 25, 2023',
#  'October 26, 2023',
#  'October 27, 2023',
#  'September 01, 2020',
#  'September 07, 2022',
#  'September 08, 2023',
#  'September 09, 2021',
#  'September 09, 2022',
#  'September 21, 2020',
#  'September 22, 2023',
#  'September 23, 2020',
#  'September 24, 2021',
#  'September 26, 2023',
#  'September 27, 2021',
#  'September 27, 2023',
#  'September 28, 2021',
#  'September 28, 2022',
#  'September 28, 2023',
#  'September 30, 2020',
#  'September 30, 2022'}

# %%
speech_df['Date']= pd.to_datetime(speech_df['Date'])
speech_df.merge(daily_return,on='Date').to_csv('withreturnlong.csv')

# %%
speech_df.merge(move.reset_index(),on='Date').to_csv('withrangelong.csv')

# %%
move=(price.High- price.Low)/price.Close
move.reset_index()
# Out:
#            Date   BTC-USD  DX-Y.NYB
# 0    2020-01-01  0.011026       NaN
# 1    2020-01-02  0.039637  0.004543
# 2    2020-01-03  0.067900  0.004131
# 3    2020-01-04  0.015906       NaN
# 4    2020-01-05  0.019425       NaN
# ...         ...       ...       ...
# 1503 2024-02-12  0.050737  0.003648
# 1504 2024-02-13  0.039240  0.009432
# 1505 2024-02-14  0.052570  0.003056
# 1506 2024-02-15  0.027888  0.005081
# 1507 2024-02-16  0.017189  0.004794
#
# [1508 rows x 3 columns]

# %%
price

# %%
stack = []
mapping = {')': '(', '}': '{', ']': '['}
stack.pop()

# %%
def isValid(s):
    stack = []
    mapping = {')': '(', '}': '{', ']': '['}

    for char in s:
        if char in mapping:
            if stack and stack[-1] == mapping[char]:  # Checking if stack is not empty before popping
                stack.pop()
            else:
                return False
        else:
            stack.append(char)

    return not stack
isValid('{Class}')

# %%
not []

# %%
ll[-1]

# %%
# Fibonacci using memoization
memo = {}
def fib(n):
    print(n)
    if n in memo:
        return memo[n]
    if n <= 1:
        return n
    memo[n] = fib(n-1) + fib(n-2)

    return memo[n]

# Example usage:
# print(fib(5))  # Output: 5

# %%
fib(20)

# %%
speeches.drop_duplicates(subset='Text').to_csv('nodupspeeches.csv')

# %%
speech_df
# Out:
#                   Date                                     Speaker  \
# 0    February 16, 2024  Vice Chair for Supervision Michael S. Barr
# 1    February 15, 2024              Governor Christopher J. Waller
# 2    February 15, 2024                 Governor Michelle W. Bowman
# 3    February 14, 2024  Vice Chair for Supervision Michael S. Barr
# 4    February 12, 2024                 Governor Michelle W. Bowman
# ..                 ...                                         ...
# 222  February 10, 2021                      Chair Jerome H. Powell
# 223   January 13, 2021               Vice Chair Richard H. Clarida
# 224   January 13, 2021                      Governor Lael Brainard
# 225   January 12, 2021                      Governor Lael Brainard
# 226   January 08, 2021               Vice Chair Richard H. Clarida
#
#                                               Location  \
# 0    At the Annual Columbia Law School Banking Conf...
# 1    At "Climate, Currency, and Central Banking," a...
# 2    At the 19th BCBS-FSI High-Level Meeting for Af...
# 3    At the 40th Annual National Association for Bu...
# 4    At the American Bankers Association 2024 Confe...
# ..                                                 ...
# 222     At the Economic Club of New York (via webcast)
# 223  At the "The Road Ahead for Central Banks," a s...
# 224  At the Inaugural Mike McCracken Lecture on Ful...
# 225  At the AI Academic Symposium hosted by the Boa...
# 226  At the C. Peter McColough Series on Internatio...
#
#                                                   Text
# 0    February 16, 2024\n\nVice Chair for Supervisio...
# 1    February 15, 2024\n\nGovernor Christopher J. W...
# 2    February 15, 2024\n\nGovernor Michelle W. Bowm...
# 3    February 14, 2024\n\nVice Chair for Supervisio...
# 4    February 12, 2024\n\nGovernor Michelle W. Bowm...
# ..                                                 ...
# 222  February 10, 2021\n\nChair Jerome H. Powell\n\...
# 223  January 13, 2021\n\nVice Chair Richard H. Clar...
# 224  January 13, 2021\n\nGovernor Lael Brainard\n\n...
# 225  January 12, 2021\n\nGovernor Lael Brainard\n\n...
# 226  January 08, 2021\n\nVice Chair Richard H. Clar...
#
# [227 rows x 4 columns]

# %%
speech_df.Location.value_counts().index
# Out:
# Index(['Peterson Institute for International Economics, Washington, D.C. ()',
#        'Money Marketeers of New York University, New York, New York',
#        'Forecasters Club of New York, New York, New York',
#        'C. Peter McColough Series on International Economics, Council on Foreign Relations, New York, New York',
#        'At "A Look at the Past, Present, and Future," a conference celebrating the Centennial of the Division of Research and Statistics, Board of Governors of the Federal Reserve System, Washington, D.C.',
#        'American Enterprise Institute, Washington, D.C.',
#        'Brookings Institution, Washington, D.C.',
#        'Hutchins Center on Fiscal and Monetary Policy, The Brookings Institution, Washington, D.C. ()',
#        'Peterson Institute for International Economics, Washington, D.C.',
#        '2022 U.S. Monetary Policy Forum, New York, New York',
#        ...
#        'At The Chicago Booth Initiative on Global Markets Workshop on Market Dysfunction, Chicago, Illinois',
#        'Mid-Size Bank Coalition of America, Los Angeles, California ()',
#        'Ec10, Principles of Economics, Lecture, Faculty of Arts and Sciences, Harvard University, Cambridge, Massachusetts',
#        'U.S. Monetary Policy Forum, New York, New York',
#        'Sadie Collective Research Reception, Washington, D.C.',
#        'Midwest Cyber Workshop, organized by the Federal Reserve Banks of Chicago, Kansas City, and St. Louis',
#        'American Bankers Association Community Banking Conference, Orlando, Florida',
#        'Global Interdependence Center Conference: Digital Money, Decentralized Finance, and the Puzzle of Crypto, La Jolla, California',
#        '2023 Arkansas State University Agribusiness Conference, Jonesboro, Arkansas',
#        'Urban Institute, Washington, D.C.'],
#       dtype='object', length=260)

# %%
speeches.Speaker.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-9164420282ea> in <module>
# ----> 1 speeches.Speaker.value_counts()
#
# NameError: name 'speeches' is not defined

# %%
set(speech_df.Speaker)
# Out:
# {'Chair Jerome H. Powell',
#  'Governor Adriana D. Kugler',
#  'Governor Christopher J. Waller',
#  'Governor Lael Brainard',
#  'Governor Lisa D. Cook',
#  'Governor Michelle W. Bowman',
#  'Governor Philip N. Jefferson',
#  'Vice Chair Richard H. Clarida',
#  'Vice Chair for Supervision Michael S. Barr',
#  'Vice Chair for Supervision Randal K. Quarles'}

# %%
speeches['Text'].str.split().map(len).mean()
# Out:
# 2465.1511111111113
